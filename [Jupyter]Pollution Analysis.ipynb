# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Python Project Dataset.csv", encoding="UTF-8")

print("\nSample Data:")
print(df.head())

print("\nMissing Values:")
print(df.isnull().sum())
dfc = df.dropna(subset=['pollutant_min', 'pollutant_max', 'pollutant_avg'])
# Out:
# Sample Data:
#   country  state     city                         station  \
# 0   India  Bihar  Chhapra  Darshan Nagar, Chhapra - BSPCB
# 1   India  Bihar     Gaya      Collectorate, Gaya - BSPCB
# 2   India  Bihar     Gaya        Kareemganj, Gaya - BSPCB
# 3   India  Bihar     Gaya        Kareemganj, Gaya - BSPCB
# 4   India  Bihar     Gaya     SFTI Kusdihra, Gaya - BSPCB
#
#            last_update   latitude  longitude pollutant_id  pollutant_min  \
# 0  08-04-2025 22:00:00  25.780826  84.744677        OZONE            6.0
# 1  08-04-2025 22:00:00  24.795500  84.999400          NO2            2.0
# 2  08-04-2025 22:00:00  24.792403  84.992416        PM2.5           40.0
# 3  08-04-2025 22:00:00  24.792403  84.992416           CO           32.0
# 4  08-04-2025 22:00:00  24.762518  84.982348          NO2           19.0
#
#    pollutant_max  pollutant_avg
# 0           95.0           53.0
# 1           10.0            6.0
# 2          137.0           68.0
# ...

# %%
avg = dfc.groupby('city')['pollutant_avg'].mean()
sort= avg.sort_values(ascending=False)
top_city = sort.head(10)
plt.figure(figsize=(10, 5))
sns.barplot(x=top_city.values, y=top_city.index, palette="viridis")
plt.title("Top 10 Most Polluted Cities")
plt.xlabel("Average Pollutant Level")
plt.ylabel("City")
plt.show()
# Out:
# C:\Users\phani\AppData\Local\Temp\ipykernel_9128\742112368.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_city.values, y=top_city.index, palette="viridis")

# %%
pollutant_counts = dfc['pollutant_id'].value_counts()
plt.figure(figsize=(8, 4))
sns.barplot(x=pollutant_counts.index, y=pollutant_counts.values, palette="magma")
plt.title("Pollutant Type Frequency")
plt.xlabel("Pollutant ID")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\phani\AppData\Local\Temp\ipykernel_9128\2518278630.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=pollutant_counts.index, y=pollutant_counts.values, palette="magma")

# %%
plt.figure(figsize=(6, 5))
data = dfc[['pollutant_min', 'pollutant_max', 'pollutant_avg']]
cor=data.corr()
sns.heatmap(cor,annot=True,cmap='coolwarm')
plt.title("Correlation Between Pollutant Metrics")
plt.show()

# %%
dfc.to_csv("Cleaned_Pollution_Data.csv", index=False)
print("\nCleaned data saved to 'Cleaned_Pollution_Data.csv'.")
# Out:
# Cleaned data saved to 'Cleaned_Pollution_Data.csv'.
